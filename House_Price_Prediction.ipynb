# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec1a3fda-703d-435f-a835-a88a0152fb78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec1a3fda-703d-435f-a835-a88a0152fb78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('/content/practiceDataset.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data['LotFrontage'] = data['LotFrontage'].fillna(data['LotFrontage'].mean())

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X = data[['MSSubClass','MSZoning','LotFrontage','LotArea','HouseStyle','OverallQual','OverallCond']]
X
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea HouseStyle  OverallQual  \
# 0             60       RL         65.0     8450     2Story            7
# 1             20       RL         80.0     9600     1Story            6
# 2             60       RL         68.0    11250     2Story            7
# 3             70       RL         60.0     9550     2Story            7
# 4             60       RL         84.0    14260     2Story            8
# ...          ...      ...          ...      ...        ...          ...
# 1455          60       RL         62.0     7917     2Story            6
# 1456          20       RL         85.0    13175     1Story            6
# 1457          70       RL         66.0     9042     2Story            7
# 1458          20       RL         68.0     9717     1Story            5
# 1459          20       RL         75.0     9937     1Story            5
#
#       OverallCond
# 0               5
# 1               8
# 2               5
# 3               5
# ...

# %%
Y = data['SalePrice']
Y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_MSZoning = LabelEncoder()
le_HouseStyle = LabelEncoder()

# %%
X['MSZoning'] = le_MSZoning.fit_transform(X['MSZoning'])
X['HouseStyle'] = le_MSZoning.fit_transform(X['HouseStyle'])

# %%
X.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  HouseStyle  OverallQual  \
# 0          60         3         65.0     8450           5            7
# 1          20         3         80.0     9600           2            6
# 2          60         3         68.0    11250           5            7
# 3          70         3         60.0     9550           5            7
# 4          60         3         84.0    14260           5            8
#
#    OverallCond
# 0            5
# 1            8
# 2            5
# 3            5
# 4            5

# %%
model = LinearRegression()
model.fit(X.values,Y)
# Out:
# LinearRegression()

# %%
price = [[55,2,77.0,8000,4,8,5]]
result = model.predict(price)
print(result)
# Out:
# [266762.19274741]

# %%
print('The price of the House is {0} Rupees'.format(result))
# Out:
# The price of the House is [266762.19274741] Rupees
